# %%
# !git clone https://github.com/ZurMaD/RRIN
# Out:
# Cloning into 'RRIN'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 98 (delta 41), reused 56 (delta 16), pack-reused 0
# Unpacking objects: 100% (98/98), done.

# %%
# %cd RRIN
# Out:
# /content/RRIN

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip3 install -r requirements.txt

# %%
import gdown, subprocess

url = 'https://drive.google.com/uc?id=1HeXmFYsF6ObXEHSU42lUaniNUqJKg0xf'
output = '/content/RRIN/pretrained_model.pth.tar'
gdown.download(url, output, quiet=False)

print("Correctly downloaded")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1HeXmFYsF6ObXEHSU42lUaniNUqJKg0xf
# To: /content/RRIN/pretrained_model.pth.tar
# 76.8MB [00:00, 233MB/s]
# Correctly downloaded

# %%
# !rm -rf /content/RRIN/data/input_*
# !rm -v /content/RRIN/data/input/*


#####################
#     FROM VIDEO    #
#####################

import gdown, subprocess

url = 'https://drive.google.com/uc?id=1_VquAJ3PisL-4aCcq0170FhpVRQrWQm3'
output = '/content/RRIN/data/video.mp4'
gdown.download(url, output, quiet=False)
md5 = '26ed1018d8ec8240c5a5d5d9eeb35d6d'
gdown.cached_download(url, output, md5=md5, postprocess=gdown.extractall)
cmd_shell = "ffmpeg -i /content/RRIN/data/video.mp4 -vf fps=24 /content/RRIN/data/input/%d.png; rm /content/RRIN/data/video.mp4" #; rm /content/RRIN/data/frames.zip
subprocess.call(cmd_shell, shell=True)

print("Correctly downloaded")

###############################
#     FROM ZIP WITH FRAMES    #
###############################
# Out:
# Correctly downloaded

# %%
# !ls /content/RRIN/data/input/
# Out:
# 1000.png  1471.png  1941.png  2410.png	2881.png  3350.png  3820.png  530.png
# 1001.png  1472.png  1942.png  2411.png	2882.png  3351.png  3821.png  531.png
# 1002.png  1473.png  1943.png  2412.png	2883.png  3352.png  3822.png  532.png
# 1003.png  1474.png  1944.png  2413.png	2884.png  3353.png  3823.png  533.png
# 1004.png  1475.png  1945.png  2414.png	2885.png  3354.png  3824.png  534.png
# 1005.png  1476.png  1946.png  2415.png	2886.png  3355.png  3825.png  535.png
# 1006.png  1477.png  1947.png  2416.png	2887.png  3356.png  3826.png  536.png
# 1007.png  1478.png  1948.png  2417.png	2888.png  3357.png  3827.png  537.png
# 1008.png  1479.png  1949.png  2418.png	2889.png  3358.png  3828.png  538.png
# 1009.png  147.png   194.png   2419.png	288.png   3359.png  3829.png  539.png
# 100.png   1480.png  1950.png  241.png	2890.png  335.png   382.png   53.png
# 1010.png  1481.png  1951.png  2420.png	2891.png  3360.png  3830.png  540.png
# ...

# %%
# !python3 interpolate_frames.py --testpath '/content/RRIN/data/' --subfolder 'input' --multiplier 2
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-08-27 06:06:02.272128 /content/RRIN/data/input_x4/167611.png
# 2020-08-27 06:06:02.949934 /content/RRIN/data/input_x4/167701.png
# 2020-08-27 06:06:03.638992 /content/RRIN/data/input_x4/167711.png
# 2020-08-27 06:06:04.330175 /content/RRIN/data/input_x4/167801.png
# 2020-08-27 06:06:05.023254 /content/RRIN/data/input_x4/167811.png
# 2020-08-27 06:06:05.716281 /content/RRIN/data/input_x4/167901.png
# 2020-08-27 06:06:06.418568 /content/RRIN/data/input_x4/167911.png
# 2020-08-27 06:06:07.117856 /content/RRIN/data/input_x4/168001.png
# 2020-08-27 06:06:07.813705 /content/RRIN/data/input_x4/168011.png
# 2020-08-27 06:06:08.514558 /content/RRIN/data/input_x4/168101.png
# 2020-08-27 06:06:09.217072 /content/RRIN/data/input_x4/168111.png
# 2020-08-27 06:06:09.906194 /content/RRIN/data/input_x4/168201.png
# 2020-08-27 06:06:10.598644 /content/RRIN/data/input_x4/168211.png
# ...

# %%
# Count files frames
# !ls /content/RRIN/data/input_x4 | wc -l
# Out:
# 16701

# %%
# !rm /content/RRIN/frames_x2_out_rrin.zip
# !rm /content/RRIN/frames_x4_out_rrin.zip

# !zip -r /content/RRIN/frames_x2_out_rrin.zip /content/RRIN/data/input_x2
# !zip -r /content/RRIN/frames_x4_out_rrin.zip /content/RRIN/data/input_x4
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/RRIN/data/input_x4/309800.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/275800.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/333101.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/331801.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/287601.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/53301.png (deflated 1%)
#   adding: content/RRIN/data/input_x4/207410.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/376100.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/240301.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/309200.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/267301.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/130400.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/127411.png (deflated 0%)
#   adding: content/RRIN/data/input_x4/378910.png (deflated 0%)
# ...

# %%
# !ls  /content/RRIN/data/input_x4

# %%
# !ls -l
# Out:
# total 4522836
# drwxr-xr-x 6 root root       4096 Aug 27 04:45 data
# -rw-r--r-- 1 root root       1653 Aug 27 03:52 demo.py
# -rw-r--r-- 1 root root 4554521470 Aug 27 07:14 frames_out_rrin.zip
# -rw-r--r-- 1 root root       4910 Aug 27 04:46 interpolate_frames.py
# -rw-r--r-- 1 root root       1907 Aug 27 03:52 model.py
# -rw-r--r-- 1 root root   76818924 Aug 27 04:03 pretrained_model.pth.tar
# drwxr-xr-x 2 root root       4096 Aug 27 03:57 __pycache__
# -rw-r--r-- 1 root root       2555 Aug 27 03:52 README.md
# -rw-r--r-- 1 root root         61 Aug 27 04:02 requirements.txt
# -rw-r--r-- 1 root root       3051 Aug 27 03:52 unet.py

# %%
fps=24*2**2
print(fps)
# Out:
# 96

# %%
# !ffmpeg -f image2 -i "/content/RRIN/data/input_x2/%*.png" "/content/out_rrin_x2.mp4"
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
#-c:v libx264 -pix_fmt yuv420p 
#!ffmpeg -f image2 -framerate 96 -i "/content/RRIN/data/input_x4/%*.png" -start_number 100 -c:v libx264 -pix_fmt yuv420p "/content/out_rrin_x4.mp4" 
# !ffmpeg -f image2 -i "/content/RRIN/data/input_x4/%*.png" "/content/out_rrin_x4.mp4"
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import shutil
from datetime import datetime

try:
  shutil.move("/content/RRIN/frames_x2_out_rrin.zip", "/content/gdrive/My Drive/frames_x2_out_rrin.zip")
  shutil.move("/content/RRIN/frames_x4_out_rrin.zip", "/content/gdrive/My Drive/frames_x4_out_rrin.zip")
  shutil.move("/content/out_rrin_x2.mp4", "/content/gdrive/My Drive/video_x2_output_rrin.mp4")
  shutil.move("/content/out_rrin_x4.mp4", "/content/gdrive/My Drive/video_x4_output_rrin.mp4")
except Exception as e:
  print(e)
